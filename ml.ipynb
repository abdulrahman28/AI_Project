# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulrahman28/AI_Project/blob/master/ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.uniform(1.0,1.0,1000)
y = np.random.uniform(1.0,2.0,1000)

plt.plot(y)
plt.show()
